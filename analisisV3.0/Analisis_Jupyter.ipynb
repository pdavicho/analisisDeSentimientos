# %%
import pandas as pd

# %% [markdown]
# # Lasso

# %%
dfLasso = pd.read_csv("lassoTweet.csv")
dfLasso.head()
# Out:
#                        created at                         Usuario  \
# 0  Wed Feb 24 13:30:27 +0000 2021  Milton Rolando Rodríguez Farah
# 1  Wed Feb 24 13:01:48 +0000 2021  Angeles 🤓 Mode #DiosNosProteja
# 2  Wed Feb 24 12:43:25 +0000 2021              Fernando Gavilanes
# 3  Wed Feb 24 12:40:01 +0000 2021                         Marifer
# 4  Wed Feb 24 12:31:46 +0000 2021                 Alegria Sols 🇪🇨
#
#                                                Tweet Lugar  rtCount  \
# 0  RT @CesarMongeO: #ElEcuadorDelEncuentro\n#Lass...   NaN       14
# 1  Toda Latinoamerica esta contaminada de sociali...   NaN        0
# 2  @LassoGuillermo es el único que puede unir al ...   NaN        0
# 3  RT @guido_chiriboga: Hoy revisamos el plan de ...   NaN        2
# 4  #LassoPresidente2021\n#LassoPresidente2021\n#L...   NaN        0
#
#                                            pre-tweet  \
# 0  rt @cesarmongeo #elecuadordelencuentro #lassop...
# 1  toda latinoamerica contaminada socialismo21 co...
# 2  @lassoguillermo único puede unir país, calidad...
# 3  rt @guido_chiriboga hoy revisamos plan campaña...
# 4  #lassopresidente2021 #lassopresidente2021 #las...
#
#                                          clean_tweet
# 0  rt  cesarmongeo  elecuadordelencuentro  lassop...
# 1  toda latinoamerica contaminada socialismo21 co...
# 2   lassoguillermo único puede unir país  calidad...
# 3  rt  guido chiriboga hoy revisamos plan campaña...
# 4   lassopresidente2021  lassopresidente2021  las...

# %%
from datetime import datetime
def fechaFormat(date):
    newFecha = datetime.strftime(datetime.strptime(date,'%a %b %d %H:%M:%S +0000 %Y'), '%b-%d')
    return newFecha

# %%
dfLasso['FechaFormato'] = [fechaFormat(date) for date in dfLasso['created at']]
dfLasso.head()
# Out:
#                        created at                         Usuario  \
# 0  Wed Feb 24 13:30:27 +0000 2021  Milton Rolando Rodríguez Farah
# 1  Wed Feb 24 13:01:48 +0000 2021  Angeles 🤓 Mode #DiosNosProteja
# 2  Wed Feb 24 12:43:25 +0000 2021              Fernando Gavilanes
# 3  Wed Feb 24 12:40:01 +0000 2021                         Marifer
# 4  Wed Feb 24 12:31:46 +0000 2021                 Alegria Sols 🇪🇨
#
#                                                Tweet Lugar  rtCount  \
# 0  RT @CesarMongeO: #ElEcuadorDelEncuentro\n#Lass...   NaN       14
# 1  Toda Latinoamerica esta contaminada de sociali...   NaN        0
# 2  @LassoGuillermo es el único que puede unir al ...   NaN        0
# 3  RT @guido_chiriboga: Hoy revisamos el plan de ...   NaN        2
# 4  #LassoPresidente2021\n#LassoPresidente2021\n#L...   NaN        0
#
#                                            pre-tweet  \
# 0  rt @cesarmongeo #elecuadordelencuentro #lassop...
# 1  toda latinoamerica contaminada socialismo21 co...
# 2  @lassoguillermo único puede unir país, calidad...
# 3  rt @guido_chiriboga hoy revisamos plan campaña...
# 4  #lassopresidente2021 #lassopresidente2021 #las...
#
#                                          clean_tweet FechaFormato
# 0  rt  cesarmongeo  elecuadordelencuentro  lassop...       Feb-24
# 1  toda latinoamerica contaminada socialismo21 co...       Feb-24
# 2   lassoguillermo único puede unir país  calidad...       Feb-24
# 3  rt  guido chiriboga hoy revisamos plan campaña...       Feb-24
# 4   lassopresidente2021  lassopresidente2021  las...       Feb-24

# %%
dfLasso["Persona"] = "Lasso"
dfLasso.head()
# Out:
#                        created at                         Usuario  \
# 0  Wed Feb 24 13:30:27 +0000 2021  Milton Rolando Rodríguez Farah
# 1  Wed Feb 24 13:01:48 +0000 2021  Angeles 🤓 Mode #DiosNosProteja
# 2  Wed Feb 24 12:43:25 +0000 2021              Fernando Gavilanes
# 3  Wed Feb 24 12:40:01 +0000 2021                         Marifer
# 4  Wed Feb 24 12:31:46 +0000 2021                 Alegria Sols 🇪🇨
#
#                                                Tweet Lugar  rtCount  \
# 0  RT @CesarMongeO: #ElEcuadorDelEncuentro\n#Lass...   NaN       14
# 1  Toda Latinoamerica esta contaminada de sociali...   NaN        0
# 2  @LassoGuillermo es el único que puede unir al ...   NaN        0
# 3  RT @guido_chiriboga: Hoy revisamos el plan de ...   NaN        2
# 4  #LassoPresidente2021\n#LassoPresidente2021\n#L...   NaN        0
#
#                                            pre-tweet  \
# 0  rt @cesarmongeo #elecuadordelencuentro #lassop...
# 1  toda latinoamerica contaminada socialismo21 co...
# 2  @lassoguillermo único puede unir país, calidad...
# 3  rt @guido_chiriboga hoy revisamos plan campaña...
# 4  #lassopresidente2021 #lassopresidente2021 #las...
#
#                                          clean_tweet FechaFormato Persona
# 0  rt  cesarmongeo  elecuadordelencuentro  lassop...       Feb-24   Lasso
# 1  toda latinoamerica contaminada socialismo21 co...       Feb-24   Lasso
# 2   lassoguillermo único puede unir país  calidad...       Feb-24   Lasso
# 3  rt  guido chiriboga hoy revisamos plan campaña...       Feb-24   Lasso
# 4   lassopresidente2021  lassopresidente2021  las...       Feb-24   Lasso

# %%
from plotnine import ggplot, aes, geom_line, geom_histogram

# %%
(ggplot(dfLasso, aes(x=dfLasso['FechaFormato'], fill=dfLasso['Persona'])) + geom_histogram(position='identity',bins=20))
# Out:
# <ggplot: (143122635840)>

# %% [markdown]
# # Yaku

# %%
dfYaku = pd.read_csv("yakuTweet.csv")
dfYaku.head()
# Out:
#                        created at               Usuario  \
# 0  Wed Feb 24 13:32:40 +0000 2021  NoticieroEcuadoradio
# 1  Wed Feb 24 13:32:25 +0000 2021           Radio Quito
# 2  Wed Feb 24 13:32:24 +0000 2021     Patricio Estrella
# 3  Wed Feb 24 13:25:20 +0000 2021         tom dieusaert
# 4  Wed Feb 24 12:03:02 +0000 2021        Rosa Rodríguez
#
#                                                Tweet Lugar  rtCount  \
# 0  #YakuPérez dio a conocer que contaban con cerc...   NaN        0
# 1  #YakuPérez dio a conocer que contaban con cerc...   NaN        0
# 2  RT @ErmelRosario: 🆘️YAKU PÉREZ, POR SU MALDAD ...   NaN        7
# 3  #yakuperez #Ecuador geeft het nog niet op. Vol...   NaN        0
# 4  RT @ecuadorenvivo: #AHORA: #YakuPérez, represe...   NaN       25
#
#                                            pre-tweet  \
# 0  #yakupérez dio conocer contaban cerca 16 000 #...
# 1  #yakupérez dio conocer contaban cerca 16 000 #...
# 2  rt @ermelrosario 🆘️yaku pérez, maldad presiden...
# 3  #yakuperez #ecuador geeft het nog niet op volg...
# 4  rt @ecuadorenvivo #ahora #yakupérez, represent...
#
#                                          clean_tweet
# 0   yakupérez dio conocer contaban cerca 16 000  ...
# 1   yakupérez dio conocer contaban cerca 16 000  ...
# 2  rt  ermelrosario   yaku pérez  maldad presiden...
# 3   yakuperez  ecuador geeft het nog niet op volg...
# 4  rt  ecuadorenvivo  ahora  yakupérez  represent...

# %%
dfYaku['FechaFormato'] = [fechaFormat(date) for date in dfYaku['created at']]
dfYaku.head()
# Out:
#                        created at               Usuario  \
# 0  Wed Feb 24 13:32:40 +0000 2021  NoticieroEcuadoradio
# 1  Wed Feb 24 13:32:25 +0000 2021           Radio Quito
# 2  Wed Feb 24 13:32:24 +0000 2021     Patricio Estrella
# 3  Wed Feb 24 13:25:20 +0000 2021         tom dieusaert
# 4  Wed Feb 24 12:03:02 +0000 2021        Rosa Rodríguez
#
#                                                Tweet Lugar  rtCount  \
# 0  #YakuPérez dio a conocer que contaban con cerc...   NaN        0
# 1  #YakuPérez dio a conocer que contaban con cerc...   NaN        0
# 2  RT @ErmelRosario: 🆘️YAKU PÉREZ, POR SU MALDAD ...   NaN        7
# 3  #yakuperez #Ecuador geeft het nog niet op. Vol...   NaN        0
# 4  RT @ecuadorenvivo: #AHORA: #YakuPérez, represe...   NaN       25
#
#                                            pre-tweet  \
# 0  #yakupérez dio conocer contaban cerca 16 000 #...
# 1  #yakupérez dio conocer contaban cerca 16 000 #...
# 2  rt @ermelrosario 🆘️yaku pérez, maldad presiden...
# 3  #yakuperez #ecuador geeft het nog niet op volg...
# 4  rt @ecuadorenvivo #ahora #yakupérez, represent...
#
#                                          clean_tweet FechaFormato
# 0   yakupérez dio conocer contaban cerca 16 000  ...       Feb-24
# 1   yakupérez dio conocer contaban cerca 16 000  ...       Feb-24
# 2  rt  ermelrosario   yaku pérez  maldad presiden...       Feb-24
# 3   yakuperez  ecuador geeft het nog niet op volg...       Feb-24
# 4  rt  ecuadorenvivo  ahora  yakupérez  represent...       Feb-24

# %%
dfYaku["Persona"] = "Yaku"
dfYaku.head()
# Out:
#                        created at               Usuario  \
# 0  Wed Feb 24 13:32:40 +0000 2021  NoticieroEcuadoradio
# 1  Wed Feb 24 13:32:25 +0000 2021           Radio Quito
# 2  Wed Feb 24 13:32:24 +0000 2021     Patricio Estrella
# 3  Wed Feb 24 13:25:20 +0000 2021         tom dieusaert
# 4  Wed Feb 24 12:03:02 +0000 2021        Rosa Rodríguez
#
#                                                Tweet Lugar  rtCount  \
# 0  #YakuPérez dio a conocer que contaban con cerc...   NaN        0
# 1  #YakuPérez dio a conocer que contaban con cerc...   NaN        0
# 2  RT @ErmelRosario: 🆘️YAKU PÉREZ, POR SU MALDAD ...   NaN        7
# 3  #yakuperez #Ecuador geeft het nog niet op. Vol...   NaN        0
# 4  RT @ecuadorenvivo: #AHORA: #YakuPérez, represe...   NaN       25
#
#                                            pre-tweet  \
# 0  #yakupérez dio conocer contaban cerca 16 000 #...
# 1  #yakupérez dio conocer contaban cerca 16 000 #...
# 2  rt @ermelrosario 🆘️yaku pérez, maldad presiden...
# 3  #yakuperez #ecuador geeft het nog niet op volg...
# 4  rt @ecuadorenvivo #ahora #yakupérez, represent...
#
#                                          clean_tweet FechaFormato Persona
# 0   yakupérez dio conocer contaban cerca 16 000  ...       Feb-24    Yaku
# 1   yakupérez dio conocer contaban cerca 16 000  ...       Feb-24    Yaku
# 2  rt  ermelrosario   yaku pérez  maldad presiden...       Feb-24    Yaku
# 3   yakuperez  ecuador geeft het nog niet op volg...       Feb-24    Yaku
# 4  rt  ecuadorenvivo  ahora  yakupérez  represent...       Feb-24    Yaku

# %%
(ggplot(dfYaku, aes(x=dfYaku['FechaFormato'], fill=dfYaku['Persona'])) + geom_histogram(position='identity',bins=20))
# Out:
# <ggplot: (143122635849)>

# %% [markdown]
# ## Uniendo Frames

# %%
frames = [dfLasso, dfYaku]
df = pd.concat(frames)
df.count()
# Out:
# created at      2783
# Usuario         2783
# Tweet           2783
# Lugar             89
# rtCount         2783
# pre-tweet       2783
# clean_tweet     2783
# FechaFormato    2783
# Persona         2783
# dtype: int64

# %%
(ggplot(df, aes(x=df['FechaFormato'], fill=df['Persona'])) + geom_histogram(position='identity',bins=20))
# Out:
# <ggplot: (143124823333)>
